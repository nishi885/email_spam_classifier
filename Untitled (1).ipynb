# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\vishal\Desktop\spam.csv",
    encoding="latin-1"
)

df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 4633   ham        These won't do. Have to move on to morphine        NaN
# 4097   ham   I think just yourself Û_Thanks and see you tomo        NaN
# 2836   ham                            1's reach home call me.        NaN
# 4544   ham  Never y lei... I v lazy... Got wat? Dat day Ì_...        NaN
# 1977  spam  Reply to win å£100 weekly! Where will the 2006...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4633        NaN        NaN
# 4097        NaN        NaN
# 2836        NaN        NaN
# 4544        NaN        NaN
# 1977        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed:2','Unnamed:3','Unnamed:4'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(columns=['Unnamed:2','Unnamed:3','Unnamed:4'],inplace=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 211    ham                         Home so we can always chat        NaN
# 2974   ham      Don't worry, * is easy once have ingredients!        NaN
# 1354   ham  Baaaaabe! I misss youuuuu ! Where are you ? I ...        NaN
# 2631  spam  URGENT! Your mobile No 077xxx WON a å£2,000 Bo...        NaN
# 2182   ham                   PS U no ur a grown up now right?        NaN
#
#      Unnamed: 3 Unnamed: 4
# 211         NaN        NaN
# 2974        NaN        NaN
# 1354        NaN        NaN
# 2631        NaN        NaN
# 2182        NaN        NaN

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 4999  ham  Well its not like you actually called someone ...
# 2042  ham     Me not waking up until 4 in the afternoon, sup
# 5105  ham  I wnt to buy a BMW car urgently..its vry urgen...
# 5329  ham                      Sir, waiting for your letter.
# 5509  ham  Lol they were mad at first but then they woke ...
